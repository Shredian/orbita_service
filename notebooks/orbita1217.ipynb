# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime as dt

# %%
import numpy as np

# %%
data = pd.read_excel("321/1.xlsx")
data.head(30)
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#     Номер        Дата            Клиент              Модель  Вид  \
# 0   16614  07.04.2012     Рахманин А.С.          Nokia 7230  сот
# 1   16618  07.04.2012     Асташкин А.Н.         Nokia C5-00  сот
# 2   16624  09.04.2012      Денисов Ю.А.         Nokia C5-00  сот
# 3   16647  13.04.2012      Ходунов М.И.          Nokia 6233  сот
# 4   16667  17.04.2012       Валуев С.А.           ASUS P550  сот
# 5   16677  19.04.2012   Безаботнов Д.В.    Samsung GT-B7722  сот
# 6   16681  19.04.2012   Милосердов А.В.           iPhone 3g  сот
# 7   16684  19.04.2012    Сондарева Н.В.    Samsung GT-S5250  сот
# 8   16686  20.04.2012      Рыбаков Ю.В.    Samsung GT-S3100  сот
# 9   16717  25.04.2012     Смирнова О.В.    Samsung GT-S5250  сот
# ...

# %%
data = data.drop(["Номер.1", "Дата.1", "Клиент.1", "Вид.1", "Модель.1", "IMEI / SN.1", "Неисправность.1", "Комментарии.1",
                  "Комментарии наши.1", "Состояние.1", "Сумма.1", "Работа.1", "Мастер.1", "Выдача.1", "Оплата в кассу.1", "Внешний вид.1", "Тип.1", "План.1", "Комплектация.1", "Детали.1"], axis=1)

# %%
data_sample = data.sample(100)

# %%
pd.to_ec

# %%
df['Сумма'].sum()
# Out:
# 48534290

# %%
fig = plt.figure()

fig.set_size_inches(16, 10)

sns.countplot(data=df, x = df['Мастер']).set_title("Кол-во заказов по мастерам")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по мастерам')

# %%
data['Дата'] = pd.to_datetime(data['Дата'])

# %%
sns.countplot(data=data, x = data['Дата'].dt.month).set_title("Кол-во заказов по месяцам")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по месяцам')

# %%
sns.countplot(data=df, x = df['Дата'].dt.month).set_title("Кол-во заказов по месяцам")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по месяцам')

# %%
sns.countplot(data=data, x = data['Дата'].dt.year).set_title("Кол-во заказов по годам")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по годам')

# %%
sns.countplot(data=df, x = df['Дата'].dt.year).set_title("Кол-во заказов по годам")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по годам')

# %%
sns.countplot(data=data, x = data['Дата'].dt.weekday).set_title("Кол-во заказов по дням недели")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по дням недели')

# %%
sns.countplot(data=df, x = df['Дата'].dt.weekday).set_title("Кол-во заказов по дням недели")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по дням недели')

# %%
fig, ax = plt.subplots()

counts = data['Вид'].value_counts()
filtered_values = counts[counts > 200].index.tolist()
filtered_df = data[data['Вид'].isin(filtered_values)]

sns.countplot(data=filtered_df, x = filtered_df['Вид']).set_title("Кол-во заказов по виду техники")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по виду техники')

# %%
fig, ax = plt.subplots()

counts = df['Вид'].value_counts()
filtered_values = counts[counts > 200].index.tolist()
filtered_df = df[df['Вид'].isin(filtered_values)]

sns.countplot(data=filtered_df, x=filtered_df['Вид']).set_title("Кол-во заказов по виду техники")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по виду техники')

# %%
counts
# Out:
# Вид
# ЖК т/в           2099
# т/в              1651
# мц                821
# ноутбук           592
# сот               509
#                  ...
# DVD-LCD             1
# gps навигатор       1
# cd dvd              1
# моно                1
# магн                1
# Name: count, Length: 64, dtype: int64

# %%
sns.barplot(x=data['Дата'].dt.month, y="Сумма", data=data, estimator=sum)
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Дата', ylabel='Сумма'>

# %%
counts = data['Мастер'].value_counts()
filtered_values = counts[counts > 100].index.tolist()
filtered_df = data[data['Мастер'].isin(filtered_values)]
sns.barplot(x=filtered_df['Мастер'], y="Сумма", data=filtered_df, estimator=sum)
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Мастер', ylabel='Сумма'>

# %%
filtered_df = data.loc[(data['Дата'] >= '2015-01-01')
                     & (data['Дата'] < '2015-12-31')]
# filtered_df.tail()
sns.barplot(x=filtered_df['Дата'].dt.month, y="Сумма", data=filtered_df, estimator=sum)
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Дата', ylabel='Сумма'>

# %%
counts = data['Вид'].value_counts()
filtered_values = counts[counts > 180].index.tolist()
filtered_df = data[data['Вид'].isin(filtered_values)]

sns.barplot(data=filtered_df, x = filtered_df['Вид'], y = filtered_df["Сумма"], estimator=sum).set_title("Кол-во заказов по виду техники")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по виду техники')

# %%
filtered_df = data.loc[(data['Дата'] >= '2013-01-01')
                       & (data['Дата'] < '2016-12-31')]

sns.countplot(data=filtered_df, x = filtered_df['Дата'].dt.month).set_title("Кол-во заказов по месяцам")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Кол-во заказов по месяцам')

# %%
sum_minus_components = data['Сумма'] - data['Детали']

# %%
sum_minus_components.sum()
# Out:
# 20671135

# %%
data.describe()
# Out:
#               Номер                           Дата         Сумма  \
# count  11413.000000                          11358  11413.000000
# mean   22302.037764  2014-11-16 03:01:02.757527808   2189.663542
# min    16598.000000            2012-04-05 00:00:00      0.000000
# 25%    19451.000000            2013-07-31 00:00:00    800.000000
# 50%    22302.000000            2014-11-08 00:00:00   2000.000000
# 75%    25154.000000            2016-02-27 00:00:00   3000.000000
# max    28007.000000            2017-09-09 00:00:00  35000.000000
# std     3293.488020                            NaN   1915.644699
#
#              Работа                         Выдача  \
# count  11413.000000                          10712
# mean    1811.192062  2014-11-22 03:37:22.270351104
# min        0.000000            2012-04-06 00:00:00
# 25%      800.000000            2013-08-05 18:00:00
# 50%     1650.000000            2014-11-12 00:00:00
# 75%     2500.000000            2016-03-02 00:00:00
# ...

# %%
counts = data['Неисправность'].value_counts()
counts
# Out:
# Неисправность
# не включается               3591
# нет изображения              401
# не читает диски              339
# нет звука                    237
# ЛПМ                          215
#                             ...
# "PROTECT"                      1
# неисправен трансфокатор        1
# зависает при наборе            1
# включается выключается         1
# пятна, полосы, артефакты       1
# Name: count, Length: 3345, dtype: int64

# %%
data_jk = pd.read_excel("jk.xlsx")
data_jk['Дата'] = pd.to_datetime(data_jk['Дата'], format='%d.%m.%Y')
data_jk.head(30)
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#     Номер       Дата           Клиент                 Модель     Вид  \
# 0   16635 2012-04-10      Козлов Ю.В.         Toshiba 14JL7R  ЖК т/в
# 1   16641 2012-04-11    Заварзин Б.Г.       SHARP LC-26SV1RU  ЖК т/в
# 2   16646 2012-04-13    Логашков Е.В.          Novex NL-1994  ЖК т/в
# 3   16655 2012-04-16     Зубарев В.Ю.     Mystery MTV-3214LW  ЖК т/в
# 4   16666 2012-04-17      Иванов В.П.    Philips 32PF9531/10  ЖК т/в
# 5   16668 2012-04-17    Астапчук С.Д.       SHARP LC-32D44RU  ЖК т/в
# 6   16673 2012-04-18    Касьянов Н.В.  Philips 20PFL4112S/60  ЖК т/в
# 7   16675 2012-04-18     Кечкина О.Ю.    Philips 20PF5121/58  ЖК т/в
# 8   16701 2012-04-23  Гончаренко В.Д.            BBK LT1514S  ЖК т/в
# ...

# %%
filtered_df_jk = data_jk.loc[(data_jk['Дата'] >= '2012-01-01')
                       & (data_jk['Дата'] < '2023-12-31')]

sns.barplot(x=filtered_df_jk['Дата'].dt.year, y="Работа", data=filtered_df_jk, estimator="mean")
# data_jk['Сумма'].sum()
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Дата', ylabel='Работа'>

# %%
data_music = pd.read_excel("music.xlsx")
data_music['Дата'] = pd.to_datetime(data_music['Дата'], format='%d.%m.%Y')
data_music.head(30)
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#     Номер       Дата            Клиент               Модель Вид IMEI / SN  \
# 0   16610 2012-04-07  Кузниченков А.В.         LG LM-K5530X  мц      2710
# 1   16619 2012-04-07       Другов Д.А.    Philips AZ1574/00  мц      6996
# 2   16620 2012-04-07  Береговский О.А.       Hyundai H-1416  мц      0219
# 3   16680 2012-04-19  Шаймарданов Т.Р.    Panasonic SA-CH32  мц      7168
# 4   16688 2012-04-20   Перипечкин В.А.  GoldStar FFH-L301LX  мц      0580
# 5   16696 2012-04-21        Седов М.В.         Aiwa CX-LMN5  мц   5158328
# 6   16697 2012-04-21    Гайдаенко И.И.        Sony HCD-RX90  мц   3043165
# 7   16708 2012-04-24     Сусликов В.Д.           LG XC-U12X  мц      1174
# ...

# %%
filtered_df_music = data_music.loc[(data_music['Дата'] >= '2012-01-01')
                             & (data_music['Дата'] < '2023-12-31')]

sns.barplot(x=filtered_df_music['Дата'].dt.year, y="Работа", data=filtered_df_music, estimator="mean")
# data_music['Работа'].sum()
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Дата', ylabel='Работа'>

# %%
data_tel = pd.read_excel("television.xlsx")
data_tel['Дата'] = pd.to_datetime(data_tel['Дата'], format='%d.%m.%Y')
# data_music.head(30)
filtered_df_tel = data_tel.loc[(data_tel['Дата'] >= '2012-01-01')
                                 & (data_tel['Дата'] < '2023-12-31')]

sns.barplot(x=filtered_df_tel['Дата'].dt.year, y="Работа", data=filtered_df_tel, estimator="mean")
# data_music['Работа'].sum()
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
data_usil = pd.read_excel("usil.xlsx")
data_usil['Дата'] = pd.to_datetime(data_usil['Дата'], format='%d.%m.%Y')
# data_music.head(30)
filtered_df_usil = data_usil.loc[(data_usil['Дата'] >= '2012-01-01')
                                   & (data_usil['Дата'] < '2023-12-31')]

sns.barplot(x=filtered_df_usil['Дата'].dt.year, y="Работа", data=filtered_df_usil, estimator="mean")
# data_music['Работа'].sum()
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
data_4_types = pd.concat([data_usil, data_tel, data_jk, data_music])
# data_4_types.sample(10)
filtered_df_4_types = data_4_types.loc[(data_4_types['Дата'] >= '2023-01-01')
                                 & (data_4_types['Дата'] < '2023-12-31')]

sns.barplot(x=filtered_df_4_types['Дата'].dt.month, y="Работа", data=filtered_df_4_types, estimator="sum")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Дата', ylabel='Работа'>

# %%
import glob
print(glob.glob("desktop/*.xlsx"))
files = glob.glob("desktop/*.xlsx")
df =  pd.DataFrame()
for file in files:
    temp = pd.read_excel(file)
    df = pd.concat([df, temp])
df['Дата'] = pd.to_datetime(df['Дата'], format='%d.%m.%Y')
df['Дата'] = pd.to_datetime(df['Дата'], format='%d.%m.%Y')
df = df.drop(["Номер.1", "Дата.1", "Клиент.1", "Вид.1", "Модель.1", "IMEI / SN.1", "Неисправность.1", "Комментарии.1",
                  "Комментарии наши.1", "Состояние.1", "Сумма.1", "Работа.1", "Мастер.1", "Выдача.1", "Оплата в кассу.1", "Внешний вид.1", "Тип.1", "План.1", "Комплектация.1", "Детали.1"], axis=1)
df.Дата.value_counts()
df = df.sort_values(by="Дата")
df.shape()
# df_sample.to_excel("output.xlsx")
# Out:
# ['desktop\\1.xlsx', 'desktop\\10.xlsx', 'desktop\\100.xlsx', 'desktop\\101.xlsx', 'desktop\\102.xlsx', 'desktop\\103.xlsx', 'desktop\\104.xlsx', 'desktop\\105.xlsx', 'desktop\\106.xlsx', 'desktop\\107.xlsx', 'desktop\\108.xlsx', 'desktop\\109.xlsx', 'desktop\\11.xlsx', 'desktop\\110.xlsx', 'desktop\\111.xlsx', 'desktop\\112.xlsx', 'desktop\\113.xlsx', 'desktop\\114.xlsx', 'desktop\\115.xlsx', 'desktop\\116.xlsx', 'desktop\\117.xlsx', 'desktop\\118.xlsx', 'desktop\\119.xlsx', 'desktop\\12.xlsx', 'desktop\\120.xlsx', 'desktop\\121.xlsx', 'desktop\\122.xlsx', 'desktop\\123.xlsx', 'desktop\\124.xlsx', 'desktop\\125.xlsx', 'desktop\\126.xlsx', 'desktop\\127.xlsx', 'desktop\\128.xlsx', 'desktop\\129.xlsx', 'desktop\\13.xlsx', 'desktop\\130.xlsx', 'desktop\\131.xlsx', 'desktop\\132.xlsx', 'desktop\\133.xlsx', 'desktop\\134.xlsx', 'desktop\\135.xlsx', 'desktop\\136.xlsx', 'desktop\\137.xlsx', 'desktop\\138.xlsx', 'desktop\\139.xlsx', 'desktop\\14.xlsx', 'desktop\\140.xlsx', 'desktop\\141.xls
# ...

# %%
df.sample(200)
# Out:
#       Номер       Дата           Клиент              Модель     Вид  \
# 1277  25310 2016-03-29     Левкова С.М.      Sony KV-M1400K     т/в
# 232   32693 2020-11-09     Никулин И.В.      Sony MHC-V77DW     NaN
# 166   18037 2012-11-27     Светлов С.Ю.     SHARP LC-15SH1E  ЖК т/в
# 518   20112 2013-11-02       Актов А.В.   Thomson 40M71NH20  ЖК т/в
# 33    17813 2012-10-17     Денисов В.А.      Sony DVP-FX750    dvd
# ...     ...        ...              ...                 ...     ...
# 1630  27801 2017-07-18     Пахомов А.Н.  Funai TV-2000A MK7     т/в
# 23    30868 2019-07-06     Охреьенко ИБ   atlanta atn-156`1     NaN
# 534   35961 2023-07-08  Смородинов Н.В.     DENON PMA-510ae    усил
# 43    22428 2014-11-27  Коронкевич П.Н.      ASUS EXA1004EH      бп
# 685   20966 2014-03-24   Козаченко Г.Ю.   Loewe Xelos SL 20  ЖК т/в
#
#       IMEI / SN                       Неисправность     Комментарии  \
# 1277       2584                           нет звука            1700
# ...

# %%
df = df.sort_values(by="Дата")

# %%
df.sample(2000)
# Out:
#       Номер       Дата          Клиент               Модель      Вид  \
# 932   22589 2014-12-20     Щедрин В.В.          Sharp 21FN1      т/в
# 1393  25926 2016-07-19   Ашмонтас А.К.        Daewoo KR21S7      т/в
# 723   21131 2014-04-21     Швачко А.А.  Horizont 70CTV-698T      т/в
# 575   27696        NaT  Савельева И.В.          ASUS Eee PC  ноутбук
# 81    20332 2013-12-04   Киндяков В.П.  Panasonic NN-GX36WF      свч
# ...     ...        ...             ...                  ...      ...
# 174   24670 2015-12-08   Кириллов К.В.        Вега 10У-120С     усил
# 178   19583 2013-08-22     Блудов А.В.     Samsung GT-S8600      сот
# 1099  23753 2015-07-13   Мерцалов И.Б.  Philips 21PT136B/58      т/в
# 3844  34306 2022-02-21    Самылев В.П.          OLTO 24H337   ЖК т/в
# 343   21037 2014-04-04     Барков Г.А.       Philips AZ1018       мц
#
#             IMEI / SN             Неисправность        Комментарии  \
# 932              4129               отключается               2000
# ...

# %%
df = df.drop(["Номер.1", "Дата.1", "Клиент.1", "Вид.1", "Модель.1", "IMEI / SN.1", "Неисправность.1", "Комментарии.1",
              "Комментарии наши.1", "Состояние.1", "Сумма.1", "Работа.1", "Мастер.1", "Выдача.1", "Оплата в кассу.1", "Внешний вид.1", "Тип.1", "План.1", "Комплектация.1", "Детали.1"], axis=1)

# %%
# data_music.head(30)
filtered_df = df.loc[(df['Дата'] >= '2022-01-01')
                                 & (df['Дата'] < '2022-12-31')]

sns.barplot(x=filtered_df['Дата'].dt.month, y="Работа", data=filtered_df, estimator="sum")
# Out:
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\leo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Дата', ylabel='Работа'>

# %%
df['Тип'].value_counts()
# Out:
# Тип
# Пл.      12597
# Повт.      145
# Гар.         3
# Name: count, dtype: int64

# %%
import glob

print(glob.glob("123333/*.xls"))
files = glob.glob("123333/*.xls")
df = pd.DataFrame()
for file in files:
    temp = pd.read_excel(file)
    df = pd.concat([df, temp])
# df['Дата'] = pd.to_datetime(df['Дата'], format='%d.%m.%Y')
# df['Дата'] = pd.to_datetime(df['Дата'], format='%d.%m.%Y')
# df = df.drop(["Номер.1", "Дата.1", "Клиент.1", "Вид.1", "Модель.1", "IMEI / SN.1", "Неисправность.1", "Комментарии.1",
#               "Комментарии наши.1", "Состояние.1", "Сумма.1", "Работа.1", "Мастер.1", "Выдача.1", "Оплата в кассу.1",
#               "Внешний вид.1", "Тип.1", "План.1", "Комплектация.1", "Детали.1"], axis=1)
# df.Дата.value_counts()
# df = df.sort_values(by="Дата")
df.to_excel("output_all.xlsx")
# Out:
# ['123333\\1.xls', '123333\\10.xls', '123333\\100.xls', '123333\\101.xls', '123333\\102.xls', '123333\\103.xls', '123333\\104.xls', '123333\\105.xls', '123333\\106.xls', '123333\\107.xls', '123333\\108.xls', '123333\\109.xls', '123333\\11.xls', '123333\\110.xls', '123333\\111.xls', '123333\\112.xls', '123333\\113.xls', '123333\\114.xls', '123333\\115.xls', '123333\\116.xls', '123333\\117.xls', '123333\\118.xls', '123333\\119.xls', '123333\\12.xls', '123333\\120.xls', '123333\\121.xls', '123333\\122.xls', '123333\\123.xls', '123333\\124.xls', '123333\\125.xls', '123333\\126.xls', '123333\\127.xls', '123333\\128.xls', '123333\\129.xls', '123333\\13.xls', '123333\\130.xls', '123333\\131.xls', '123333\\132.xls', '123333\\133.xls', '123333\\134.xls', '123333\\135.xls', '123333\\136.xls', '123333\\137.xls', '123333\\138.xls', '123333\\139.xls', '123333\\14.xls', '123333\\140.xls', '123333\\141.xls', '123333\\142.xls', '123333\\143.xls', '123333\\144.xls', '123333\\145.xls', '123333\\146.xls
# ...

# %%
data = pd.read_excel("test.xlsx")
data.head(30)
# Out:
#     Íîìåð        Äàòà           Êëèåíò              Ìîäåëü  Âèä  IMEI / SN  \
# 0   27386  18.04.2017    Êîðíå÷óê Í.Â.       Panasonic l36  NaN        355
# 1   27884  07.08.2017       ïîòàïîâ åå        Sony CDP-790  NaN       8587
# 2   28362  16.11.2017    Ñàìâåëîâ Â.Í.     philips bdp5500  NaN       5364
# 3   29294  20.06.2018    Ñàâåëüåâ Å.À.     Ýëåêòðîíèêà 332  NaN      26099
# 4   30079  14.12.2018       Òîìîâ Ï.Ò.        Sony WM-FX50  NaN          -
# 5   30160  05.01.2019         Ñåìèí ÂÂ  Panasonic RQ-SX97F  NaN     000000
# 6   30223  18.01.2019       âîëîäèí ìè   Panasonic rq-a320  NaN       1111
# 7   30262  28.01.2019      Êëåùåâ Þ.Â.       Sony WM-FX483  NaN          -
# 8   30375  22.02.2019         Ãèðèí ÑÂ  Panasonic rq-cr15v  NaN  000000000
# 9   30719  27.05.2019     Õó÷ðàåâ Ê.Ì.   Panasonic RQ-V190  NaN          -
# 10  31988  16.04.2020     Äèòÿòåâ Ï.Ä.       Sanyo M-G38DT  NaN          -
# ...

# %%
from xls2xlsx import XLS2XLSX
x2x = XLS2XLSX("123333/68.xls")
x2x.to_xlsx("test.xlsx")
# Out:
# WARNING *** file size (11152) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# 'test.xlsx'

# %%
import glob
print(glob.glob("desktop/*.xlsx"))
files = glob.glob("desktop/*.xlsx")
df =  pd.DataFrame()
for file in files:
    temp = pd.read_excel(file)
    df = pd.concat([df, temp])
df['Дата'] = pd.to_datetime(df['Дата'], format='%d.%m.%Y')
# df['Дата'] = pd.to_datetime(df['Дата'], format='%d.%m.%Y')
df = df.drop(["Номер.1", "Дата.1", "Клиент.1", "Вид.1", "Модель.1", "IMEI / SN.1", "Неисправность.1", "Комментарии.1",
              "Комментарии наши.1", "Состояние.1", "Сумма.1", "Работа.1", "Мастер.1", "Выдача.1", "Оплата в кассу.1", "Внешний вид.1", "Тип.1", "План.1", "Комплектация.1", "Детали.1"], axis=1)
df.Дата.value_counts()
df = df.sort_values(by="Дата")
df.shape()
# df_sample.to_excel("output.xlsx")
df.to_excel("output_all_new.xlsx")

# %%
data = pd.read_excel("data_last.xlsx")
data.sample(20)
# Out:
#        Unnamed: 0  Номер       Дата            Клиент               Модель  \
# 15796          74  32727 2020-11-17  Мартемьянов В.Ф,        Вега МП-122 С
# 2636           16  19228 2013-07-02      Лебедев Д.В.       Behringer B912
# 16727        2047  33738 2021-09-21     Ситников М.Д.        Рубин  55M-04
# 3757          569  20361 2013-12-07        Есина Е.В.      SHARP LC-15SH1E
# 5874          323  22483 2014-12-05      Терехин В.В.      Nokia Lumia 620
# 9348         1651  25998 2016-08-03      Семенов В.В,     Sony KDL-40NX720
# 5408          861  22015 2014-09-19     Кулагина Т.И.    Samsung Ck-338CVR
# 14714         202  31577 2019-12-17    Чернецкий И.В.           Volta M-12
# 2222          375  18812 2013-04-23      Морозов В.А.         Erisson 1465
# 8764         1513  25393 2016-04-11  Василевская Ю.А.  Philips 20PF4121/58
# 10773          93  27469 2017-05-05      Сахаров О.А.      Microlab SOLO 7
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score, roc_curve, auc

# X = data.drop(["Unnamed: 0", 'Response', "Номер", "Дата", "Клиент", "Модель", "IMEI / SN", "Комментарии", "Комментарии наши", "Комплектация", "Состояние"], axis=1)
X = data[["Вид", "Неисправность", "Мастер"]]
# X.dropna()
X = pd.get_dummies(X, columns=['Вид', 'Неисправность', 'Мастер'], drop_first=True)
y = data['Сумма']

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=0,
                                                    shuffle=True,
                                                    test_size=0.2)

# %%
def mean_target_encoding(df, target, columns):
    for column in columns:
        mean_enc = df.groupby(column)[target].mean()
        df[column+'_m'] = df[column].map(mean_enc)
    return (df)
target = 'Сумма'
column = ['Вид', 'Неисправность', 'Мастер']
X = data[["Вид", "Неисправность", "Мастер", 'Сумма']]
mean_target_encoding(X, target, column)
X.head()
# Out:
# C:\Users\leo\AppData\Local\Temp\ipykernel_24356\792980027.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column+'_m'] = df[column].map(mean_enc)
# C:\Users\leo\AppData\Local\Temp\ipykernel_24356\792980027.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column+'_m'] = df[column].map(mean_enc)
# C:\Users\leo\AppData\Local\Temp\ipykernel_24356\792980027.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.model_selection import train_test_split
def mean_target_encoding(df, target, columns):
    for column in columns:
        mean_enc = df.groupby(column)[target].mean()
        df[column+'_m'] = df[column].map(mean_enc)
    return (df)
target = 'Сумма'
column = ['Вид', 'Неисправность', 'Мастер']
X = data[["Вид", "Неисправность", "Мастер", 'Сумма']]
mean_target_encoding(X, target, column)
X = X.dropna()
y = X['Сумма']
X = X[["Вид_m", "Неисправность_m", "Мастер_m"]]

# X = pd.get_dummies(X, columns=['Вид', 'Неисправность', 'Мастер'], drop_first=True)


X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=0,
                                                    shuffle=True,
                                                    test_size=0.2)
# Out:
# C:\Users\leo\AppData\Local\Temp\ipykernel_24356\2130612619.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column+'_m'] = df[column].map(mean_enc)
# C:\Users\leo\AppData\Local\Temp\ipykernel_24356\2130612619.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column+'_m'] = df[column].map(mean_enc)
# C:\Users\leo\AppData\Local\Temp\ipykernel_24356\2130612619.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor

### Your code is here
model = GradientBoostingRegressor()
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# 0.5200314974521472

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import KFold

selector = KFold(n_splits=4)

scores = []

for train_index, test_index in selector.split(X):

    X_train, X_test = X.values[train_index], X.values[test_index]
    Y_train, Y_test = y.values[train_index], y.values[test_index]

    ### Фитим исключительно на трейне!
    scaler = MinMaxScaler()
    scaler.fit(X_train)

    ### Применяем обученный scaler на трейн и тест
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    ### max_iter иногда требуется ставить побольше,
    ### особенно когда данных много и/или они сложные
    ### этот параметр регулирует верхнюю границу кол-ва
    ### итераций во время обучения
    ### подробнее - в документации

    ### По дефолту здесь параметр регуляризации alpha=1

    model_lasso = Lasso(max_iter=100000, alpha=0.1)
    model_lasso.fit(X_train_scaled, Y_train)

    predictions = model_lasso.predict(X_test_scaled)

    scores.append(np.mean(abs(predictions - Y_test)))


print(f"MSLE на Кросс-валидации равен: {np.mean(scores)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 38
#      33     predictions = model_lasso.predict(X_test_scaled)
#      35     scores.append(abs(predictions - Y_test))
# ---> 38 print(f"MSLE на Кросс-валидации равен: {np.mean(scores)}")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py:102, in _mean(a, axis, dtype, out, keepdims, where)
#     101 def _mean(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
# --> 102     arr = asanyarray(a)
# ...

# %%
predicted_values = model.predict(X_test)

# Создаем таблицу с индексами, предсказанными значениями и реальными значениями
results = pd.DataFrame({'predicted': predicted_values, 'actual': y_test})
results.head(100)
# Out:
#          predicted  actual
# 7496   2270.232379    2000
# 11701  4512.681444    4800
# 10626  4711.511419    3800
# 4509   3912.633930    5200
# 4309   3821.037681    2400
# ...            ...     ...
# 11497  3967.480170    3000
# 4918   5227.286229    3000
# 10686  4242.026766    3600
# 5744   3912.633930    4000
# 12124  2166.970160    2500
#
# [100 rows x 2 columns]

# %%
X.head()
# Out:
#          Вид_m  Неисправность_m     Мастер_m
# 0          NaN      2584.913939  3039.021221
# 1  1967.410340      2100.000000  3039.021221
# 2  4434.351145      2666.666667  3418.571835
# 3  2117.469880         0.000000          NaN
# 4   967.647059      2584.913939          NaN

# %%
def bar_sum_filtered_by_month(data_frame, date_start:str='2023-01-01', date_end:str='2023-12-31', by_column:str='Сумма'):
    new_df = data_frame.loc[(data_frame['Дата'] >= date_start)
                         & (data_frame['Дата'] < date_end)]
    sns.barplot(x=new_df['Дата'].dt.month, y=by_column, data=new_df, estimator=sum)

# %%
def bar_sum_filtered_by_year(data_frame, date_start:str='2012-01-01', date_end:str='2023-12-31', by_column:str='Сумма'):
    new_df = data_frame.loc[(data_frame['Дата'] >= date_start)
                            & (data_frame['Дата'] < date_end)]
    sns.barplot(x=new_df['Дата'].dt.year, y=by_column, data=new_df, estimator=sum)
